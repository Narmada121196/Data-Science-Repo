# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('E:/Hero Vired/7.Pandas_Numpy/archive (1)/owid-covid-data.csv')

# %%
df.tail()
# Out:
#        iso_code continent  location        date  total_cases  new_cases  \
# 166321      ZWE    Africa  Zimbabwe  2022-03-01     236871.0      491.0
# 166322      ZWE    Africa  Zimbabwe  2022-03-02     237503.0      632.0
# 166323      ZWE    Africa  Zimbabwe  2022-03-03     237503.0        0.0
# 166324      ZWE    Africa  Zimbabwe  2022-03-04     238739.0     1236.0
# 166325      ZWE    Africa  Zimbabwe  2022-03-05     239019.0      280.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 166321             413.000        5395.0         0.0                1.000
# 166322             416.286        5396.0         1.0                1.143
# 166323             362.286        5396.0         0.0                0.857
# 166324             467.429        5397.0         1.0                0.714
# 166325             459.429        5397.0         0.0                0.571
#
#         ...  female_smokers  male_smokers  handwashing_facilities  \
# ...

# %%
df.iloc[166:,25:40]
# Out:
#         new_tests  total_tests  total_tests_per_thousand  \
# 166           NaN          NaN                       NaN
# 167           NaN          NaN                       NaN
# 168           NaN          NaN                       NaN
# 169           NaN          NaN                       NaN
# 170           NaN          NaN                       NaN
# ...           ...          ...                       ...
# 166321        NaN          NaN                       NaN
# 166322        NaN    2085373.0                   138.176
# 166323        NaN          NaN                       NaN
# 166324        NaN    2090217.0                   138.497
# 166325        NaN          NaN                       NaN
#
#         new_tests_per_thousand  new_tests_smoothed  \
# 166                        NaN                 NaN
# 167                        NaN                 NaN
# 168                        NaN                 NaN
# 169                        NaN                 NaN
# ...

# %% [markdown]
# # Questions
# 1. Which country had the most deaths, plot a bar graph of top 10.
# 2. In the 4th week of feburary 2020, which country had the most new cases.
# 3. Create a column week, denoting the week of the month and plot the tragectory of new cases added on weekly basis for the country India.
# 4. If we look at the data on a weekly basis, which country rapidly increased their testing rate the most.
# 5. Taking que from the previous question, looking at the data on a weekly basis, which country rapidly increased their vaccination rate the most.

# %% [markdown]
# #### Question 1

# %%
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 166321      ZWE    Africa     Zimbabwe  2022-03-01     236871.0      491.0
# 166322      ZWE    Africa     Zimbabwe  2022-03-02     237503.0      632.0
# 166323      ZWE    Africa     Zimbabwe  2022-03-03     237503.0        0.0
# 166324      ZWE    Africa     Zimbabwe  2022-03-04     238739.0     1236.0
# 166325      ZWE    Africa     Zimbabwe  2022-03-05     239019.0      280.0
#
# ...

# %%
df.iloc[:,4]
# Out:
# 0              5.0
# 1              5.0
# 2              5.0
# 3              5.0
# 4              5.0
#             ...
# 166321    236871.0
# 166322    237503.0
# 166323    237503.0
# 166324    238739.0
# 166325    239019.0
# Name: total_cases, Length: 166326, dtype: float64

# %%
df.groupby('location').sum()['total_deaths'].sort_values(ascending=False)[:10].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='location'>

# %%
df.groupby('location')['total_deaths'].sum().sort_values(ascending=False)[:10].plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='location'>

# %% [markdown]
# # Before start of date , week, year questions (2,3,4)

# %%
df[["year", "month", "day"]] = df["date"].str.split("-", expand = True)
df.head(10)
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1      AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# 5      AFG      Asia  Afghanistan  2020-02-29          5.0        0.0
# 6      AFG      Asia  Afghanistan  2020-03-01          5.0        0.0
# 7      AFG      Asia  Afghanistan  2020-03-02          5.0        0.0
# 8      AFG      Asia  Afghanistan  2020-03-03          5.0        0.0
# 9      AFG      Asia  Afghanistan  2020-03-04          5.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# ...

# %%
df['month']=df['month'].astype(str).astype(int)
df['year']=df['year'].astype(str).astype(int)
df['day']=df['day'].astype(str).astype(int)
df.dtypes
# Out:
# iso_code                                    object
# continent                                   object
# location                                    object
# date                                        object
# total_cases                                float64
#                                             ...
# excess_mortality                           float64
# excess_mortality_cumulative_per_million    float64
# year                                         int32
# month                                        int32
# day                                          int32
# Length: 70, dtype: object

# %% [markdown]
# ### Question 2
# In the 4th week of feburary 2021, which country had the most new cases.

# %%
df
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan  2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan  2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan  2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan  2020-02-28          5.0        0.0
# ...         ...       ...          ...         ...          ...        ...
# 166321      ZWE    Africa     Zimbabwe  2022-03-01     236871.0      491.0
# 166322      ZWE    Africa     Zimbabwe  2022-03-02     237503.0      632.0
# 166323      ZWE    Africa     Zimbabwe  2022-03-03     237503.0        0.0
# 166324      ZWE    Africa     Zimbabwe  2022-03-04     238739.0     1236.0
# 166325      ZWE    Africa     Zimbabwe  2022-03-05     239019.0      280.0
#
# ...

# %%
df['date']=pd.to_datetime(df['date'])
df['week_of_the_year'] = df['date'].dt.isocalendar().week
df['week_of_the_year']
# Out:
# 0         9
# 1         9
# 2         9
# 3         9
# 4         9
#          ..
# 166321    9
# 166322    9
# 166323    9
# 166324    9
# 166325    9
# Name: week_of_the_year, Length: 166326, dtype: UInt32

# %%
df
# Out:
#        iso_code continent     location       date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan 2020-02-24          5.0        5.0
# 1           AFG      Asia  Afghanistan 2020-02-25          5.0        0.0
# 2           AFG      Asia  Afghanistan 2020-02-26          5.0        0.0
# 3           AFG      Asia  Afghanistan 2020-02-27          5.0        0.0
# 4           AFG      Asia  Afghanistan 2020-02-28          5.0        0.0
# ...         ...       ...          ...        ...          ...        ...
# 166321      ZWE    Africa     Zimbabwe 2022-03-01     236871.0      491.0
# 166322      ZWE    Africa     Zimbabwe 2022-03-02     237503.0      632.0
# 166323      ZWE    Africa     Zimbabwe 2022-03-03     237503.0        0.0
# 166324      ZWE    Africa     Zimbabwe 2022-03-04     238739.0     1236.0
# 166325      ZWE    Africa     Zimbabwe 2022-03-05     239019.0      280.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
df['week_of_the_year'] == 8
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 166321    False
# 166322    False
# 166323    False
# 166324    False
# 166325    False
# Name: week_of_the_year, Length: 166326, dtype: boolean

# %%
df_week_8 = df[df['week_of_the_year'] == 8]

# %%
df_week_8
# Out:
#        iso_code continent     location       date  total_cases  new_cases  \
# 364         AFG      Asia  Afghanistan 2021-02-22      55617.0       13.0
# 365         AFG      Asia  Afghanistan 2021-02-23      55646.0       29.0
# 366         AFG      Asia  Afghanistan 2021-02-24      55664.0       18.0
# 367         AFG      Asia  Afghanistan 2021-02-25      55680.0       16.0
# 368         AFG      Asia  Afghanistan 2021-02-26      55696.0       16.0
# ...         ...       ...          ...        ...          ...        ...
# 166315      ZWE    Africa     Zimbabwe 2022-02-23     234589.0      609.0
# 166316      ZWE    Africa     Zimbabwe 2022-02-24     234967.0      378.0
# 166317      ZWE    Africa     Zimbabwe 2022-02-25     235467.0      500.0
# 166318      ZWE    Africa     Zimbabwe 2022-02-26     235803.0      336.0
# 166319      ZWE    Africa     Zimbabwe 2022-02-27     235803.0        0.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
#df_week_8['year'] = df_week_8['date'].dt.isocalendar().year

# %%
df_week_8['year'] == 2021
# Out:
# 364        True
# 365        True
# 366        True
# 367        True
# 368        True
#           ...
# 166315    False
# 166316    False
# 166317    False
# 166318    False
# 166319    False
# Name: year, Length: 3564, dtype: bool

# %%
df_week_8_year_2021 = df_week_8[df_week_8['year'] == 2021]

# %%
df_week_8_year_2021
# Out:
#        iso_code continent     location       date  total_cases  new_cases  \
# 364         AFG      Asia  Afghanistan 2021-02-22      55617.0       13.0
# 365         AFG      Asia  Afghanistan 2021-02-23      55646.0       29.0
# 366         AFG      Asia  Afghanistan 2021-02-24      55664.0       18.0
# 367         AFG      Asia  Afghanistan 2021-02-25      55680.0       16.0
# 368         AFG      Asia  Afghanistan 2021-02-26      55696.0       16.0
# ...         ...       ...          ...        ...          ...        ...
# 165951      ZWE    Africa     Zimbabwe 2021-02-24      35960.0       50.0
# 165952      ZWE    Africa     Zimbabwe 2021-02-25      35994.0       34.0
# 165953      ZWE    Africa     Zimbabwe 2021-02-26      36044.0       50.0
# 165954      ZWE    Africa     Zimbabwe 2021-02-27      36058.0       14.0
# 165955      ZWE    Africa     Zimbabwe 2021-02-28      36089.0       31.0
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# ...

# %%
x_series = df_week_8_year_2021.groupby('location').sum()['new_cases'].sort_values(ascending=False)[2:12]

# %%
x_series.plot(kind='bar')
# Out:
# <AxesSubplot:xlabel='location'>

# %%
x_series
# Out:
# location
# Europe                 1031882.0
# Upper middle income     942046.0
# European Union          775886.0
# North America           575882.0
# South America           552861.0
# Asia                    506288.0
# United States           480105.0
# Brazil                  384274.0
# Lower middle income     351747.0
# France                  151022.0
# Name: new_cases, dtype: float64

# %%
x_series.index
# Out:
# Index(['Europe', 'Upper middle income', 'European Union', 'North America',
#        'South America', 'Asia', 'United States', 'Brazil',
#        'Lower middle income', 'France'],
#       dtype='object', name='location')

# %%
import seaborn as sns
sns.barplot(x = x_series,y = x_series.index,orient='h')
# Out:
# <AxesSubplot:xlabel='new_cases', ylabel='location'>

# %% [markdown]
# ### 3. Create a column week, denoting the week of the month and plot the tragectory of new cases added on weekly basis for the country India.

# %%
## World, upper middle income and High income are the group not country and also continent names hence dropping these rows 

df.drop(df.index[df['location'].isin(["World", "Upper middle income","High income","Lower middle income","Low income","Asia",
                                     "Africa","Europe","European Union","North America","South America"])],inplace=True)

#df.drop(df.index[(df["location"] == "World"),axis=0,inplace=True)
#df.drop(df.index[(df["location"] == "Upper middle income"),axis=0,inplace=True)
#df.drop(df.index[(df["location"] == "High income"),axis=0,inplace=True)                 
df.location.unique()
# Out:
# array(['Afghanistan', 'Albania', 'Algeria', 'Andorra', 'Angola',
#        'Anguilla', 'Antigua and Barbuda', 'Argentina', 'Armenia', 'Aruba',
#        'Australia', 'Austria', 'Azerbaijan', 'Bahamas', 'Bahrain',
#        'Bangladesh', 'Barbados', 'Belarus', 'Belgium', 'Belize', 'Benin',
#        'Bermuda', 'Bhutan', 'Bolivia', 'Bonaire Sint Eustatius and Saba',
#        'Bosnia and Herzegovina', 'Botswana', 'Brazil',
#        'British Virgin Islands', 'Brunei', 'Bulgaria', 'Burkina Faso',
#        'Burundi', 'Cambodia', 'Cameroon', 'Canada', 'Cape Verde',
#        'Cayman Islands', 'Central African Republic', 'Chad', 'Chile',
#        'China', 'Colombia', 'Comoros', 'Congo', 'Cook Islands',
#        'Costa Rica', "Cote d'Ivoire", 'Croatia', 'Cuba', 'Curacao',
#        'Cyprus', 'Czechia', 'Democratic Republic of Congo', 'Denmark',
#        'Djibouti', 'Dominica', 'Dominican Republic', 'Ecuador', 'Egypt',
#        'El Salvador', 'Equatorial Guinea', 'Eritrea', 'Estonia',
# ...

# %%
# NOTE: GOT FROM STACK OVERFLOW https://stackoverflow.com/questions/3806473/week-number-of-the-month
# Above split of date into year month and day is done for this purpose 

import calendar
import numpy as np
calendar.setfirstweekday(0)

def get_week_of_month(year, month, day):
    x = np.array(calendar.monthcalendar(year, month))
    week_of_month = np.where(x==day)[0][0] + 1
    return(week_of_month)


df['week_of_month'] = df.apply(lambda x: get_week_of_month(x['year'],x['month'],x['day']),axis=1)

# %%
df['week_of_month'].unique() # week of month values will be from 4 - 6 weeks
# Out:
# array([5, 1, 2, 3, 4, 6], dtype=int64)

# %%
df[df['location'] == "India"].groupby(['week_of_month'])['new_cases'].sum().plot(kind='line',x='week_of_month')
# Out:
# <AxesSubplot:xlabel='week_of_month'>

# %% [markdown]
# ### 4. If we look at the data on a weekly basis, which country rapidly increased their testing rate the most.

# %%
# calculation according to week of the year  @ Siddharth sir - not sure 
inc_test_rate = df.groupby(['week_of_the_year','location']).sum()['total_tests'].sort_values(ascending=False)
inc_test_rate.head(20)
# Out:
# week_of_the_year  location
# 7                 United States    8.019400e+09
# 6                 United States    7.903564e+09
# 5                 United States    7.771248e+09
# 4                 United States    7.624084e+09
# 3                 United States    7.453116e+09
# 8                 United States    7.311028e+09
# 2                 United States    7.258365e+09
# 1                 United States    7.048169e+09
# 52                United States    6.781161e+09
# 7                 India            6.750347e+09
# 6                 India            6.651668e+09
# 51                United States    6.609140e+09
# 5                 India            6.534758e+09
# 50                United States    6.433384e+09
# 4                 India            6.416309e+09
# 3                 India            6.292222e+09
# 49                United States    6.263616e+09
# 48                United States    6.103299e+09
# 8                 India            6.076829e+09
# ...

# %%
inc_test_rate.head(50).plot(kind='bar',figsize=(15,10)) ## Just tried something
# Out:
# <AxesSubplot:xlabel='week_of_the_year,location'>

# %%
# Calculation according to week of month
inc_test_rate_wom = df.groupby(['week_of_month','location'])['total_tests'].sum().sort_values(ascending=False)
inc_test_rate_wom.head(20)
# Out:
# week_of_month  location
# 4              United States     5.783957e+10
# 3              United States     5.732243e+10
# 2              United States     5.598576e+10
# 4              India             4.848583e+10
# 3              India             4.678322e+10
# 2              India             4.644335e+10
# 5              United States     3.856770e+10
# 1              United States     3.449215e+10
# 5              India             3.332008e+10
# 1              India             3.113849e+10
# 4              United Kingdom    2.516076e+10
# 3              United Kingdom    2.408250e+10
# 2              United Kingdom    2.364392e+10
# 5              United Kingdom    1.690941e+10
# 1              United Kingdom    1.572778e+10
# 4              France            1.285641e+10
#                Russia            1.282093e+10
# 3              France            1.244879e+10
# 2              France            1.205007e+10
#                Russia            1.100182e+10
# ...

# %%
inc_test_rate_wom.head(100).plot(kind='bar',figsize=(20, 10))
# Out:
# <AxesSubplot:xlabel='week_of_month,location'>

# %%
##5. Taking que from the previous question, looking at the data on a weekly basis, 
## which country rapidly increased their vaccination rate the most.
vaccin_rate = df.groupby(['week_of_month','location'])['new_vaccinations'].mean().sort_values(ascending=False)[:25]
vaccin_rate
# Out:
# week_of_month  location
# 6              China            1.139850e+07
# 5              China            1.051649e+07
# 4              China            8.961024e+06
# 2              China            8.298169e+06
# 1              China            8.282360e+06
# 3              China            8.241078e+06
# 6              India            5.355008e+06
# 2              India            4.705241e+06
# 5              India            4.465908e+06
# 4              India            4.410382e+06
# 3              India            4.371672e+06
# 1              India            3.697000e+06
# 6              Brazil           1.547382e+06
# 2              United States    1.371200e+06
# 5              United States    1.278766e+06
# 6              Japan            1.208858e+06
# 3              United States    1.202170e+06
# 1              United States    1.195430e+06
# 4              United States    1.185945e+06
# 2              Pakistan         1.134983e+06
# ...

# %%
df1 = df[['location','week_of_month',"month",'new_vaccinations','year']]
df1
# Out:
#            location  week_of_month  month  new_vaccinations  year
# 0       Afghanistan              5      2               NaN  2020
# 1       Afghanistan              5      2               NaN  2020
# 2       Afghanistan              5      2               NaN  2020
# 3       Afghanistan              5      2               NaN  2020
# 4       Afghanistan              5      2               NaN  2020
# ...             ...            ...    ...               ...   ...
# 166321     Zimbabwe              1      3           10409.0  2022
# 166322     Zimbabwe              1      3            9380.0  2022
# 166323     Zimbabwe              1      3           10373.0  2022
# 166324     Zimbabwe              1      3            9508.0  2022
# 166325     Zimbabwe              1      3               NaN  2022
#
# [157899 rows x 5 columns]

# %%
df1.pivot_table(index=["location","week_of_month",'year'], values=["new_vaccinations"], aggfunc="mean").sort_values(by='new_vaccinations',ascending=False)[:20]
# Out:
#                              new_vaccinations
# location week_of_month year
# China    6             2021      1.508667e+07
#          5             2021      1.146196e+07
#          1             2021      9.950486e+06
#          4             2021      9.766232e+06
#          3             2021      8.864492e+06
#          2             2021      8.690079e+06
# India    6             2022      7.423888e+06
#          2             2022      6.653207e+06
# China    2             2022      6.534571e+06
# India    3             2022      5.606104e+06
# China    3             2022      5.435714e+06
# India    4             2022      5.130925e+06
# China    4             2022      4.992500e+06
#          5             2022      4.725500e+06
# India    6             2021      4.665382e+06
#          5             2022      4.575632e+06
#                        2021      4.449948e+06
#          2             2021      4.326470e+06
#          4             2021      4.275880e+06
# ...

# %%
## 4th question 
df.groupby(['week_of_the_year','location']).sum()['new_tests_smoothed'].sort_values(ascending=False).head(20)
# Out:
# week_of_the_year  location
# 2                 United States    30027908.0
# 3                 United States    27821620.0
# 1                 United States    27653628.0
# 51                United States    25107976.0
# 52                United States    24574416.0
# 4                 United States    24423959.0
# 50                United States    24252563.0
# 49                United States    22902424.0
# 48                United States    22162872.0
# 47                United States    21125705.0
# 5                 United States    21023475.0
# 46                United States    20817289.0
# 45                United States    19462969.0
# 23                India            18973823.0
# 6                 United States    18902279.0
# 36                India            18697949.0
# 44                United States    18361157.0
# 34                India            18341483.0
# 37                India            18328674.0
# 38                India            18256467.0
# ...
