# %%
import matplotlib

# %%
matplotlib._version_

# %%
import matplotlib as mpl

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
##generate a random number using numpy, we will generate 2 sets of random number, X and Y

# %%
x = np.linspace(0,50,100)
y = x*np.linspace(100,150,100)

# %%
plt.plot(x,y)

# %%
##Add different elements to the plot

# %%
##add title using plt.title
#add x label using 'plt.xlabel'
# add y label using 'plt.ylabel'
#add legends using 'plt.Legends'

# %%
plt.title('Newplot')
# Out:
# Text(0.5, 1.0, 'Newplot')

# %%
##Add color and style element to plot chart

# %%
plt.plot(x,y,c = 'r',linestyle = '--',linewidth = 2)

# %%
##Add markers to the plot,markers have different elements like style, color, size, etc...
plt.title("NewTitle")
plt.plot(x,y,marker = '*',markersize = 3,c='g')

# %%
##Add grid using grid()command
plt.grid(True)

# %%
##Bar Graph##
###plt.bar##
##bar() needs 2  diff arguments one for x and another for y
##x-axis will show the subject and y axis will show the marks for each subject

# %%
subject = ["English","Maths","Social","Science","Tamil"]

# %%
marks = [75,88,99,100,66]

# %%
plt.bar(subject,marks)
# Out:
# <BarContainer object of 5 artists>

# %%
##Customization
##width shows bar width,default is 0.8
##color - shows bar color
##bottom--value from where the y axis starts in the chart i.e., the lowest value
##align - to move the position of xlabel , has 2 options 'edge and 'centre'
##edgecolor - used to color the borders of the bar
##linewidth - used to adjust the width of the line around the bar
##tick_label -  to see the customized labels for x axis

# %%
plt.bar(subject,marks,color = 'g', width = 0.5, bottom = 10, align = 'center', edgecolor = 'r',linewidth = 2,tick_label = subject)
# Out:
# <BarContainer object of 5 artists>

# %%
#
